# %%
# !git clone https://github.com/hadiaramzan2199/SemEval2026-Task-10.git
# Out:
# Cloning into 'SemEval2026-Task-10'...
# remote: Enumerating objects: 444, done.
# remote: Counting objects: 100% (191/191), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 444 (delta 79), reused 48 (delta 9), pack-reused 253 (from 1)
# Receiving objects: 100% (444/444), 13.44 MiB | 18.37 MiB/s, done.
# Resolving deltas: 100% (151/151), done.
# Downloading LLM-Assignment-2/Hadia_RoBERTa/results/roberta_ner_model.pth (1.1 GB)
# Error downloading object: LLM-Assignment-2/Hadia_RoBERTa/results/roberta_ner_model.pth (fca61ff): Smudge error: Error downloading LLM-Assignment-2/Hadia_RoBERTa/results/roberta_ner_model.pth (fca61ffb3be5e270c2c72665d3f014371ced6fd902a02a887116b59331a5a666): batch response: This repository exceeded its LFS budget. The account responsible for the budget should increase it to restore access.
#
# Errors logged to /content/SemEval2026-Task-10/.git/lfs/logs/20251220T012558.498982362.log
# Use `git lfs logs last` to view the log.
# error: external filter 'git-lfs filter-process' failed
# fatal: LLM-Assignment-2/Hadia_RoBERTa/results/roberta_ner_model.pth: smudge filter lfs failed
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'

# %%
# %cd /content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf
# Out:
# /content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf

# %%
# !pip -q install transformers pytorch-crf scikit-learn

# %%
import torch
print(torch.cuda.is_available(), torch.cuda.get_device_name(0))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-1990659956.py in <cell line: 0>()
#       1 import torch
# ----> 2 print(torch.cuda.is_available(), torch.cuda.get_device_name(0))
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in get_device_name(device)
#     580         str: the name of the device
#     581     """
# --> 582     return get_device_properties(device).name
#     583
#     584
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in get_device_properties(device)
#     612         _CudaDeviceProperties: the properties of the device
#     613     """
# --> 614     _lazy_init()  # will define _get_device_properties
#     615     device = _get_device_index(device, optional=True)
#     616     if device < 0 or device >= device_count():
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     401             )
#     402         if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403             raise AssertionError("Torch not compiled with CUDA enabled")
#     404         if _cudart is None:
#     405             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
# !python train_roberta_crf.py \
  --train_path /content/SemEval2026-Task-10/LLM-Assignment-2/data/train_rehydrated.jsonl \
  --epochs 10 --batch_size 2 --grad_accum 8 --max_length 192 \
  --results_dir results --plots_dir plots

# %%
# !python evaluate_roberta_crf.py \
  --train_path /content/SemEval2026-Task-10/LLM-Assignment-2/data/train_rehydrated.jsonl \
  --model_path results/roberta_crf_best.pth
