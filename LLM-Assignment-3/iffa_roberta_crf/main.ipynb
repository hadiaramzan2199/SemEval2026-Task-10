# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJECT_ROOT = "/content/drive/MyDrive/SemEval2026/Assignment3/roberta_crf"

# %%
import os

os.makedirs(PROJECT_ROOT, exist_ok=True)
os.makedirs(f"{PROJECT_ROOT}/results", exist_ok=True)
os.makedirs(f"{PROJECT_ROOT}/plots", exist_ok=True)
os.makedirs(f"{PROJECT_ROOT}/checkpoints", exist_ok=True)

# %%
# !git clone https://github.com/hadiaramzan2199/SemEval2026-Task-10.git

# %%
#!git lfs uninstall
# Out:
# WARNING: error running /usr/lib/git-core/git 'config' '--includes' '--global' '--remove-section' 'filter.lfs': 'fatal: no such section: filter.lfs' 'exit status 128'
# Global Git LFS configuration has been removed.

# %%
# %cd /content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf
# Out:
# /content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf

# %%
# !pip -q install transformers pytorch-crf scikit-learn

# %%
# !python train_roberta_crf.py \
  --train_path /content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf/data/train_rehydrated.jsonl \
  --epochs 10 --batch_size 2 --grad_accum 8 --max_length 192 \
  --results_dir /content/drive/MyDrive/SemEval2026/roberta_crf_runs/results \
  --plots_dir /content/drive/MyDrive/SemEval2026/roberta_crf_runs/plots
# Out:
# Device: cuda
# Loading: /content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf/data/train_rehydrated.jsonl
# Train: 3452  Val: 864
# 2025-12-20 02:45:33.887968: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766198733.905143    5151 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766198733.910277    5151 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766198733.924900    5151 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate_roberta_crf.py \
  --train_path /content/SemEval2026-Task-10/LLM-Assignment-2/data/train_rehydrated.jsonl \
  --model_path /content/drive/MyDrive/SemEval2026/roberta_crf_runs/results/roberta_crf_best.pth
# Out:
# Device: cuda
# 2025-12-20 04:00:40.606038: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766203240.623655   24431 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766203240.628842   24431 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766203240.641971   24431 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
