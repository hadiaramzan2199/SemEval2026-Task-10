# %%
# !git clone https://github.com/hadiaramzan2199/SemEval2026-Task-10.git
# %cd SemEval2026-Task-10/LLM-Assignment-2/Hadia_RoBERTa
# Out:
# Cloning into 'SemEval2026-Task-10'...
# remote: Enumerating objects: 353, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 353 (delta 34), reused 38 (delta 7), pack-reused 253 (from 1)
# Receiving objects: 100% (353/353), 13.41 MiB | 15.08 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# /content/SemEval2026-Task-10/LLM-Assignment-2/Hadia_RoBERTa

# %%
# !pip install -r requirements.txt

# %%
# !pip install torch transformers datasets scikit-learn matplotlib seaborn tqdm torchcrf

# %%
# !python rehydrate_data.py
# Out:
# python3: can't open file '/content/SemEval2026-Task-10/LLM-Assignment-2/Hadia_RoBERTa/rehydrate_data.py': [Errno 2] No such file or directory

# %%
# !ls ../data
# Out:
# datasheet.md	    dev_rehydrated.jsonl  train_rehydrated.jsonl
# dev_redacted.jsonl  train_redacted.jsonl

# %%
# !python train_roberta.py \
  --train_path ../data/train_rehydrated.jsonl \
  --epochs 3 \
  --batch_size 8
# Out:
# 2025-12-19 16:37:33.955745: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766162253.975637    3630 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766162253.981511    3630 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766162253.996403    3630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate.py \
  --model_path results/roberta_ner_model.pth \
  --train_path ../data/train_rehydrated.jsonl
# Out:
# 2025-12-19 16:49:22.065412: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766162962.084709    6694 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766162962.090632    6694 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766162962.105535    6694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# %cd /content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf
# Out:
# /content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf

# %%
# !pip install torchcrf

# %%
# !python train_roberta_crf.py \
  --train_path ../../data/train_rehydrated.jsonl \
  --epochs 5 \
  --batch_size 8 \
  --model_name xlm-roberta-base
# Out:
# Traceback (most recent call last):
#   File "/content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf/train_roberta_crf.py", line 6, in <module>
#     from model_roberta_crf import RoBERTaCRF
#   File "/content/SemEval2026-Task-10/LLM-Assignment-3/iffa_roberta_crf/model_roberta_crf.py", line 4, in <module>
#     from torchcrf import CRF
# ModuleNotFoundError: No module named 'torchcrf'
